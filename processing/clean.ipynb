# %% [markdown]
# ## Clean data
#
# Clean data from bronze and save into silver

# %%
import importlib
import os
import polars as pl
from datetime import datetime, date, timedelta
from matplotlib import pyplot as plt

from pattern_detector import utils

importlib.reload(utils)
# Out:
# <module 'pattern_detector.utils' from '/home/zach/Projects/PutAnalysis/pattern_detector/utils.py'>

# %% [markdown]
# ### List of files

# %%
bronze_path = os.path.join("data", "bronze")
filenames = os.listdir(bronze_path)

nrdy_path = os.path.join("data", "NRDY.csv")

# %% [markdown]
# ### Analyzing time ranges of files
#
# ##### Checking last dates of files

# %%
last_timestamps = {}
for filename in filenames:
    ticker = filename.removesuffix(".csv")

    # read file into df
    filepath = os.path.join(bronze_path, filename)
    df = pl.read_csv(filepath)

    # make dict of last timestamps of each ticker
    last_timestamp = df["timestamp"][-1]
    if last_timestamp in last_timestamps:
        last_timestamps[last_timestamp].append(ticker)
    else:
        last_timestamps[last_timestamp] = [ticker]

for timestamp in last_timestamps:
    print(datetime.fromtimestamp(timestamp))
    print(last_timestamps[timestamp])
    print(len(last_timestamps[timestamp]))
# Out:
# 2024-09-13 06:30:00
# ['SCSC', 'JAZZ', 'HUM', 'GVP', 'KW', 'AXSM', 'TNDM', 'INSG', 'DBD', 'VGR', 'TPHS', 'NGVT', 'PBF', 'SAMG', 'WHR', 'DUK', 'GRBK', 'AGM', 'PMT', 'SITC', 'INVA', 'HOFT', 'ARCB', 'RMR', 'ADMA', 'GHM', 'PDCO', 'TGEN', 'SSKN', 'IIPR', 'HIW', 'CRBP', 'COLB', 'BYFC', 'BLFS', 'MATW', 'RNR', 'LILA', 'BLD', 'PBPB', 'UTHR', 'UGI', 'FTK', 'ZM', 'AXTA', 'FMBH', 'ALKS', 'PPIH', 'TXMD', 'KOS', 'CDXS', 'F', 'MAN', 'MO', 'NMIH', 'RAMP', 'UVE', 'NE', 'OOMA', 'AMZN', 'CSCO', 'AP', 'FPI', 'DHIL', 'MWA', 'ODFL', 'GPRO', 'SIGA', 'CEVA', 'HZO', 'ARL', 'KZR', 'APPN', 'QUIK', 'LC', 'AXGN', 'FND', 'CAR', 'TSBK', 'MUR', 'ARVN', 'HCKT', 'AEE', 'GCO', 'SRI', 'FLS', 'ISDR', 'HONE', 'SIGI', 'OSK', 'CVI', 'TFSL', 'ARW', 'SWK', 'BMY', 'EPAM', 'FATE', 'ZYXI', 'PG', 'LBRDA', 'TSQ', 'AC', 'AVAV', 'AEHR', 'LAD', 'RGS', 'EVC', 'ALL', 'PHIO', 'IVR', 'RDNT', 'TLYS', 'KAI', 'ANIK', 'FIZZ', 'CHK', 'ABCB', 'AMRC', 'AES', 'GSHD', 'HDSN', 'MSA', 'ZS', 'CARG', 'SPB', 'CMI', 'GPRE', 'HBI', 'NLY', 'MCK', 'NTLA', 'EWBC', 'IIIV', 'CDZI', 'HOPE', 'TXN', 'PHM', 'MTN', 'CBZ', 'AMTX', 'MAS', 'SXT', 'GORO', 'PGC', 'GV', 'UUU', 'UVV', 'SSTI', 'ITW', 'CRS', 'BKD', 'ALGT', 'TTGT', 'GPN', 'CASS', 'AVNS', 'MGNX', 'SSTK', 'RDFN', 'SBFG', 'SYNA', 'JKHY', 'CMS', 'PCH', 'VRNT', 'IR', 'CLDX', 'GT', 'NVAX', 'TSE', 'GNK', 'BUSE', 'WCC', 'MNR', 'ROIC', 'MPB', 'USIO', 'QRHC', 'RLJ', 'NVRO', 'AR', 'OPY', 'XOM', 'SRE', 'STX', 'WAFD', 'OCC', 'OMC', 'LOB', 'CACI', 'ACA', 'BL', 'WSC', 'LNG', 'SYK', 'FLIC', 'MDT', 'KEX', 'UHS', 'CARS', 'XEL', 'SLG', 'HQY', 'BXC', 'ENTA', 'RPD', 'SNBR', 'NBHC', 'BKH', 'WVFC', 'BTU', 'EEX', 'MVIS', 'MIND', 'HEAR', 'MOS', 'FCN', 'CVLT', 'GLW', 'MAT', 'SRNE', 'AXS', 'WEN', 'BAH', 'HRTG', 'UTI', 'CSGS', 'LSTR', 'GNW', 'MKSI', 'CKX', 'GAIA', 'NTNX', 'ALNY', 'O', 'SF', 'SIRI', 'SFIX', 'CMP', 'CASH', 'MKTX', 'ATRA', 'VSEC', 'ASRT', 'POOL', 'SND', 'PANW', 'UBER', 'SAIC', 'FIBK', 'TPR', 'SUP', 'MOTS', 'CDE', 'GTY', 'VTR', 'FMAO', 'KODK', 'MSCI', 'ANGO', 'BEAT', 'BIIB', 'CVCO', 'FLXS', 'BECN', 'AIR', 'EA', 'DGLY', 'SMTC', 'MRK', 'TRMK', 'HAFC', 'EXPD', 'ATR', 'CZWI', 'MBUU', 'FSP', 'SKX', 'X', 'AAOI', 'WH', 'UFCS', 'MHO', 'RGCO', 'SITE', 'PDLB', 'GEO', 'TENB', 'WSO', 'FIVN', 'WNC', 'CHRS', 'GWRS', 'WDAY', 'KALV', 'BCPC', 'PNRG', 'CAG', 'BA', 'ICHR', 'ALB', 'SBSI', 'OVBC', 'MCD', 'ED', 'SUPN', 'KALU', 'NWS', 'CRMD', 'APD', 'DVA', 'HTBI', 'UPS', 'CHUY', 'HCI', 'MSI', 'JEF', 'BDL', 'WSTL', 'RELL', 'OMCL', 'JILL', 'SCHW', 'PAG', 'DVAX', 'NYMT', 'LUNA', 'HASI', 'K', 'CLH', 'IBKR', 'CDXC', 'AGCO', 'USFD', 'ENSG', 'GCI', 'OUT', 'PLD', 'UE', 'CYH', 'THR', 'AVGR', 'SASR', 'NPO', 'ALEX', 'WVE', 'ATKR', 'PRFT', 'FELE', 'NOG', 'IDT', 'WDFC', 'FUL', 'CL', 'ESCA', 'PETQ', 'EFX', 'PMTS', 'NUE', 'JWN', 'IEX', 'LLY', 'AMED', 'ALLY', 'LNT', 'SWKS', 'SBRA', 'CFG', 'SJW', 'SMBC', 'HSIC', 'OSIS', 'CVNA', 'ZUO', 'HST', 'NBY', 'BKU', 'SRG', 'TSLA', 'LOW', 'NFBK', 'BSX', 'PD', 'CUZ', 'TREX', 'ARTW', 'HBAN', 'ALK', 'UFPI', 'LXRX', 'DXYN', 'CLDT', 'LASR', 'COOP', 'WINA', 'NOV', 'ARWR', 'FDBC', 'RELV', 'ICAD', 'CAKE', 'TOWN', 'DIN', 'TAP', 'TGT', 'SPGI', 'GDDY', 'ROKU', 'SVT', 'MNOV', 'KR', 'CPT', 'VRRM', 'KRO', 'ATEC', 'FNB', 'SNOA', 'HY', 'BKNG', 'KBH', 'IAC', 'B', 'SIG', 'DIT', 'CTSH', 'HCSG', 'AIV', 'SLAB', 'CENTA', 'EYE', 'VRTX', 'HPE', 'HWC', 'USAP', 'TCS', 'SHO', 'SYBX', 'BCLI', 'HLF', 'ATNI', 'NNN', 'CWBC', 'AUBN', 'ROP', 'NEON', 'OLN', 'CLRB', 'MSBI', 'IBCP', 'KLAC', 'GLDD', 'NTGR', 'PEN', 'OIS', 'HALL', 'MATX', 'STRS', 'VVI', 'MNST', 'BBSI', 'FITB', 'TAYD', 'SABR', 'LNN', 'GPK', 'RYTM', 'CHD', 'IFF', 'PBH', 'C', 'VOXX', 'NGS', 'MCFT', 'MTX', 'BR', 'BOH', 'CVR', 'FMNB', 'KMT', 'MDLZ', 'OI', 'AJX', 'KMX', 'IP', 'L', 'MLI', 'RH', 'REGN', 'ARKR', 'SBUX', 'SHW', 'CWH', 'SUI', 'CRL', 'PATK', 'NR', 'UPWK', 'NAVI', 'FISI', 'QUAD', 'SMRT', 'NCLH', 'HSON', 'WABC', 'TNXP', 'PACB', 'TPB', 'CLFD', 'BHR', 'GNL', 'EML', 'TELL', 'PKBK', 'FIX', 'SLB', 'RKDA', 'CERS', 'COO', 'FTEK', 'HUSA', 'IVAC', 'OLED', 'ATRC', 'MRO', 'CRUS', 'GENC', 'RRGB', 'HBCP', 'GTHX', 'PSA', 'UHT', 'COHR', 'LCII', 'SPOK', 'HEES', 'FBP', ' ...
# 2531
# 2024-09-12 06:30:00
# ['BDSI', 'MCBC', 'ATRI', 'AINC', 'RESI', 'LBAI', 'LSXMK', 'OSG', 'REGI', 'LSXMA', 'ETRN', 'HIBB', 'TACO', 'AGRX', 'ABIO', 'SBOW', 'NSTG', 'SLCA', 'SDPI', 'DRQ']
# 20
# 2024-08-28 13:00:00
# ['BIOC', 'AMRS', 'CNCE', 'KBAL', 'ICBK', 'ENDP', 'HZNP']
# 7
# 2024-07-18 13:00:00
# ['ACER']
# 1

# %% [markdown]
# Some tickers have only one day of data for Aug 28th, not sure why. One ticker (ACER) is missing data after Jul 18th, Yahoo has this data so potentially a bug. 20 tickers are missing the most recent day. Missing one day is fine, as I expect that they will continue to get data in the future but maybe there is some latency. For the tickers missing more than one day, I will have to remove them.

# %% [markdown]
# ##### Checking starting dates of files

# %%
first_timestamps = []
for filename in filenames:
    ticker = filename.removesuffix(".csv")

    # read file into df
    filepath = os.path.join(bronze_path, filename)
    df = pl.read_csv(filepath)

    # make dict of first timestamps of each ticker
    first_timestamp = datetime.fromtimestamp(df["timestamp"][0])
    first_timestamps.append(first_timestamp)

plt.hist(first_timestamps, bins=50)
plt.title("First dates in each ticker")
plt.show()

# %% [markdown]
# There are many tickers that only have data for the last 10 years. We will need to remove these as well.

# %% [markdown]
# Setting date limits

# %%
most_recent_date = datetime.fromtimestamp(sorted(last_timestamps)[-1]).date()
end_required = most_recent_date - timedelta(days=1)

# start 10 years before end
start_required = date(end_required.year - 10, end_required.month, end_required.day)

print(start_required)
print(end_required)
# Out:
# 2014-09-12
# 2024-09-12

# %% [markdown]
# ### Clean files
#
# - Require data for the last 10 years
# - Reformat date column
# - Combine to single parquet
# - Limit to last 10 years

# %%
combined_df = None


tickers_removed = []
for filename in filenames:
    ticker = filename.removesuffix(".csv")
    
    # read file into df
    filepath = os.path.join(bronze_path, filename)
    df = pl.read_csv(filepath)

    # convert timestamp to date
    df = df.with_columns(pl.from_epoch(df["timestamp"], time_unit="s").dt.date().alias("date"))

    # require data for the last 10 years
    if df["date"][0] > start_required or df["date"][-1] < end_required:
        tickers_removed.append(ticker)
    else:
        # limit data to last 10 years
        df = df.filter(df["date"] > start_required)

        # rename adjclose to ticker
        df = df.rename({"adjclose": ticker})

        # remove timestamp column
        df = df.select(["date", ticker])

        # join dfs
        if combined_df is not None:
            combined_df = combined_df.join(df, on="date", how="full", coalesce=True)
        else:
            combined_df = df

print(combined_df)
print("tickers removed:", len(tickers_removed), "-", tickers_removed)
# Out:
# data/NRDY.csv
# ---------------------------------------------------------------------------
# ColumnNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_2376/2526975895.py in ?()
#      13         filepath = os.path.join(bronze_path, filename)
#      14     df = pl.read_csv(filepath)
#      15
#      16     # convert timestamp to date
# ---> 17     df = df.with_columns(pl.from_epoch(df["timestamp"], time_unit="s").dt.date().alias("date"))
#      18
#      19     # require data for the last 10 years
#      20     if df["date"][0] > start_required or df["date"][-1] < end_required:
#
# ~/Projects/PutAnalysis/.venv/lib/python3.10/site-packages/polars/dataframe/frame.py in ?(self, key)
#    1342         │ 2   ┆ 5   ┆ 3   │
#    1343         │ 3   ┆ 6   ┆ 2   │
#    1344         └─────┴─────┴─────┘
#    1345         """
# -> 1346         return get_df_item_by_key(self, key)
#
# ~/Projects/PutAnalysis/.venv/lib/python3.10/site-packages/polars/_utils/getitem.py in ?(df, key)
#     156     # Single string input, e.g. df["a"]
#     157     if isinstance(key, str):
#     158         # This case is required because empty strings are otherwise treated
#     159         # as an empty Sequence in `_select_rows`
# --> 160         return df.get_column(key)
#     161
#     162     # Single input - df[1] - or multiple inputs - df["a", "b", "c"]
#     163     try:
#
# ~/Projects/PutAnalysis/.venv/lib/python3.10/site-packages/polars/dataframe/frame.py in ?(self, name, default)
#    7852         try:
#    7853             return wrap_s(self._df.get_column(name))
#    7854         except ColumnNotFoundError:
#    7855             if default is no_default:
# -> 7856                 raise
#    7857             return default
#
# ColumnNotFoundError: "timestamp" not found

# %% [markdown]
# #### Validation
#
# Checking for null values

# %%
def plot_nulls(df):
    null_df = df.null_count().transpose(include_header=True).sort("column_0", descending=True)

    null_df = null_df.filter(pl.col("column_0") > 0)
    plt.hist(null_df["column_0"], bins=20)
    plt.title("# of null values for tickers with null values")
    plt.show()

plot_nulls(combined_df)

# %% [markdown]
# Some of the columns that are missing data have a lot of data missing, but most have a small percentage of data missing. We will remove tickers with more than 5% of data missing. The rest of the nan values will be filled in as a mean.

# %% [markdown]
# #### Handling null values
# - Require 95% not nan
# - Fill nan with mean of neighbors

# %%
# remove tickers with more than 5% missing values
thinned_df = combined_df.select(col.name for col in combined_df.null_count() / combined_df.height if col.item() < 0.05)

# check remaining column null counts
plot_nulls(thinned_df)

# %%
filled_df = thinned_df.interpolate()

# check remaining column null counts
plot_nulls(filled_df)

# %% [markdown]
# At this point, the only null values are those at the start or end of the df, We can just get rid of these tickers.

# %%
cleaned_df = filled_df.select(col.name for col in filled_df.null_count() if col.item() == 0)

plot_nulls(cleaned_df)

# %% [markdown]
# There should be no null values remaining.

# %% [markdown]
# #### Calculate percent change instead of adj close

# %%
percent_df = utils.convert_to_percentage(cleaned_df)

# drop first row
percent_df = percent_df[1:]

print(percent_df)
# Out:
# shape: (2_515, 2_110)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ date      ┆ SCSC      ┆ JAZZ      ┆ HUM       ┆ … ┆ APOG      ┆ BC        ┆ SNFCA     ┆ HWBK     │
# │ ---       ┆ ---       ┆ ---       ┆ ---       ┆   ┆ ---       ┆ ---       ┆ ---       ┆ ---      │
# │ date      ┆ f64       ┆ f64       ┆ f64       ┆   ┆ f64       ┆ f64       ┆ f64       ┆ f64      │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ 2014-09-1 ┆ -0.000538 ┆ -0.012473 ┆ 0.001133  ┆ … ┆ 0.084592  ┆ 0.002705  ┆ 0.008248  ┆ 0.008148 │
# │ 7         ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 2014-09-1 ┆ 0.009414  ┆ 0.00573   ┆ 0.00498   ┆ … ┆ 0.055204  ┆ 0.008317  ┆ 0.00818   ┆ -0.00808 │
# │ 8         ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ 2        │
# │ 2014-09-1 ┆ -0.026912 ┆ 0.002512  ┆ 0.01299   ┆ … ┆ -0.024478 ┆ -0.003567 ┆ 0.004057  ┆ 0.04     │
# │ 9         ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 2014-09-2 ┆ -0.015882 ┆ -0.014055 ┆ -0.000963 ┆ … ┆ 0.001476  ┆ -0.021924 ┆ -0.010101 ┆ -0.00284 │
# │ 2         ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ 9        │
# │ 2014-09-2 ┆ -0.021703 ┆ -0.015619 ┆ -0.018029 ┆ … ┆ -0.002947 ┆ -0.017384 ┆ 0.004081  ┆ 0.0      │
# │ 3         ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ …         ┆ …         ┆ …         ┆ …         ┆ … ┆ …         ┆ …         ┆ …         ┆ …        │
# │ 2024-09-0 ┆ -0.027312 ┆ -0.006347 ┆ -0.039401 ┆ … ┆ -0.005136 ┆ 0.002252  ┆ 0.001176  ┆ -0.02017 │
# │ 9         ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ 3        │
# │ 2024-09-1 ┆ -0.01415  ┆ 0.006012  ┆ 0.007738  ┆ … ┆ 0.021132  ┆ -0.011763 ┆ -0.0047   ┆ 0.0      │
# │ 0         ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 2024-09-1 ┆ -0.011213 ┆ -0.018394 ┆ -0.052624 ┆ … ┆ -0.010427 ┆ 0.016183  ┆ 0.003542  ┆ 0.010924 │
# │ 1         ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 2024-09-1 ┆ 0.0313    ┆ 0.012556  ┆ -0.011243 ┆ … ┆ 0.010217  ┆ -0.002238 ┆ 0.011765  ┆ 0.004988 │
# │ 2         ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 2024-09-1 ┆ 0.023752  ┆ 0.021982  ┆ -0.00906  ┆ … ┆ 0.034134  ┆ 0.044058  ┆ 0.005814  ┆ 0.015006 │
# │ 3         ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# └───────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴──────────┘

# %% [markdown]
# # Calculate

# %% [markdown]
# #### Write to parquet
#
# Save in data/silver/combined.parquet

# %%
# write to parquet
out_filepath = os.path.join("data", "silver", "combined.parquet")
percent_df.write_parquet(out_filepath)
